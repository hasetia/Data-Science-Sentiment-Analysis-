# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Coronavirus, A Political Statement?
#
#
# # <font color='red'>tentative title, remember to delete/update all red notes

# %% [markdown]
# ## Permissions

# %% [markdown]
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that PIDs will be scraped from the public submission, but student names will be included.)
#
# * [  ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview <font color='red'>[add time frame because that’s important in relation to the reopening of states in present time]
#
# # <font color = red> also remember to update as overview is incomplete

# %% [markdown]
# Our project explores the official COVID-19 message updates from different populous college campuses across the United States. From the nine University of California campuses, located in California, a popular blue state, five college campuses in Texas, a popular red state, and five college campuses in Florida, a well known swing state, we attempted to measure the sentiments of these campus messages in order to analyze how states with different political ideologies are handling the virus and ensuring the safety and trust of their students. Creating csv files of messages per school and including the date and word count, we used a sentiment analysis approach and the Vader lexicon in order to analyze the sentiments of the messages. To accordingly track the progression of the sentiments in campus responses with the virus, we also paralleled the dates of the messages with the dates of the official COVID-19 confirmed cases [only include this if in the end, it supplements our report]. [If we do UC vs UC add it here and then change sentence 2 somehow so it states why we did all 9 UC’s] We found that _______.

# %% [markdown]
# # Names
#
# - Dillon Ford
# - Dylan Nelson
# - Thi Nguyen
# - Harpreet Setia
# - Bryant Tran

# %% [markdown]
# # Group Members IDs
#
# - A16092047
# - A15492704
# - A13802850
# - A14731093
# - A15404815

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there any variation in the severity of college campus’s messages across states of different political stances? Does this reflect how different political parties are paying attention to the trajectory of COVID-19?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# - Amidst the COVID-19 pandemic, it is essential to pay attention and stay up to date with reports on the ongoing crisis from our trusted leaders and officials. With this shared anxiety across the United States, people turn to their trusted state leaders in order to stay up to date with the trajectory of the virus as well as what precautions to take. As different state leaders with different ideologies are implementing different policies that they deem appropriate, this affects the updates and policies college campuses are reporting to their students to ensure their trust and safety.
# 	Within the course of this pandemic so far, it is apparent that different states are handling the spread of COVID-19 inconsistently. As the confirmed cases rapidly increased in America in mid March, states administered different shelter in place, lockdown, social distancing, and essential activity restrictions in order to reduce and slow down the spread of the virus. As 43 states administered these restrictions to varying degrees, 7 states (Arkansas, Iowa, Nebraska, North Dakota, South Dakota, Utah, and Wyoming) that are all red states, did not impose stay at home or essential activity restrictions to aid in combating the virus’s spread (1). However, we chose the state of Texas to represent our data for a red state due to the campus populations paralleling better with the state of California.
#
#
# - Although the rest of the states imposed restrictions, they varied in degree in what was still allowed to be open and to what extent they were to be closed. This included large gathering activities involving the opening beaches and of course, schools. Many college campuses responded to COVID-19 by canceling in-person instruction and converting to a remote format indefinitely while others implemented plans to stay open or planned to re-open. The variance in college responses to COVID-19 reflect the policies administered by their respective state [location] (2).
# 	Prior work has been done on the different ways colleges are responding to the pandemic when they have to take into consideration factors of how students congregate which affects the spread, their age group which affects the danger of the spread on campus, and how to relay information back to students on the changes being made which will affect the course of their future, all while also abiding by their state guidelines. This included redesigning the trajectory of the higher education system to report back to students what to expect in relation to where their state is in combating an unpredictable pandemic. Changes must be made because of this relation including disappointingly halting study abroad programs which could affect thousands of students, the structure of transitioning to remote classes at such short notice, how to make resources accessible, how long remote classes are expected to last, and what the future of in-person instruction could look like (3). The primary focus that colleges have during this pandemic is to relieve students and their families from any school related stress and instill trust into them. While doing this however, it is also crucial to ensure that college campuses are reacting accordingly and updating students as the colleges themselves receive information on the actual severity of the virus from trusted higher officials (4).
#
# -
# -
#
# 1) https://ballotpedia.org/States_that_did_not_issue_lockdown_or_stay-at-home_orders_in_response_to_the_coronavirus_(COVID-19)_pandemic,_2020
#  - This source details which states drastically differed in restrictions
#
# 2) https://www.insidehighered.com/news/2020/03/12/why-are-some-colleges-closing-over-virus-concerns-while-others-stay-open
#  - This source highlights the trajectory of different college campus instructions in relation to their state guidelines
#
# 3) https://www.npr.org/2020/03/06/812462913/6-ways-universities-are-responding-to-coronavirus
#  - This podcast calls attention to the challenges of providing campus updates regarding the pandemic while still following state orders and recommendations
#
# 4) https://www.washingtonpost.com/lifestyle/2020/03/16/college-parents-coronavirus/
#  - This article presents the importance of college campuses communicating with their students and their families to ease panic but while maintaining a realistic approach to how their state predicts the pandemic

# %% [markdown]
# # Hypothesis
#
# # <font color='red'>update this

# %% [markdown]
# Our hypothesis predicts that the communication between college campuses and their students in the red state will be _____ while the communication between college campuses and their students in the blue state will be _____. [Swing state?] <- Will said this makes sense but we might be tying in too much

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# Each dataset was created through Excel with individual team members collecting coronavirus annoucement info and compiling the information by hand from school websites. We plan to combine the datasets of different colleges within the three different states we chose in order to sufficiently differentiate any discrepancies in sentiments across states of contrasting political ideologies. This was done by importing the operating system module in python and joining separate university datasets through a for loop.
#
# - Dataset Name: allSchools.csv
#   - Link to the dataset: https://github.com/COGS108/group09_sp20/tree/master/Other%20Notebooks
#   - Number of observations: 899 rows and 6 columns
#   - Description: Collection of all school COVID-19 announcements with dates, school names, word counts, the state it originated from, and numerical values for the month (starting with 1 for January). This dataset was cleaned and formatted with data from the other individual datasets shown below.
# &nbsp;
#
# - This is the link for all datasets shown below: https://github.com/COGS108/group09_sp20/tree/master/Datasets
#
#   - Dataset Name: Florida_State_University.csv
#     - Number of observations: 41 rows
#     - Description: Date of each coronavirus annoucement along with the full text.
#
#   - Dataset Name: Texas_State_University.csv
#     - Number of observations: 46 rows
#     - Description: Date of each coronavirus annoucement along with the full text.
#
#   - Dataset Name: UC_Davis.csv
#     - Number of observations: 44 rows
#     - Description: Date of each coronavirus annoucement along with the full text and school name.
#
#   - Dataset Name: UCF.csv
#     - Number of observations: 66 rows
#     - Description: Date of each coronavirus annoucement along with the full text and link.
#
#   - Dataset Name: UC_Berkeley.csv
#     - Number of observations: 57 rows
#     - Description: Date of each coronavirus annoucement along with the full text, link, school name, and word count.
#
#   - Dataset Name: UC_Irvine.csv
#     - Number of observations: 105 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UC_Los_Angeles.csv
#     - Number of observations: 37 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UC_Merced.csv
#     - Number of observations: 73
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UC_Riverside.csv
#     - Number of observations: 56 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UC_San_Diego.csv
#     - Number of observations: 46 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UC_Santa_Barbara.csv
#     - Number of observations: 17 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, link, and word count.
#
#   - Dataset Name: UC_Santa_Cruz.csv
#     - Number of observations: 67 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: UNT.csv
#     - Number of observations: 57 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, link, and word count.
#
#   - Dataset Name: USoFlorida
#     - Number of observations: 30 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name, and word count.
#
#   - Dataset Name: U_T&M.csv
#     - Number of observations: 32 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name.
#
#   - Dataset Name: Univeristy_Austin_Texas.csv
#     - Number of observations: 28 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name.
#
#   - Dataset Name: University_Florida.csv
#     - Number of observations: 32 rows
#     - Description: Date of each coronavirus annoucement along with the full text, and school name.
#
#   - Dataset Name: University_Houston.csv
#     - Number of observations: 29 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name.
#
#   - Dataset Name: University_Miami.csv
#     - Number of observations: 39 rows
#     - Description: Date of each coronavirus annoucement along with the full text, school name.

# %% [markdown]
# # Setup

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import statsmodels.api as sm
import os

#Used in data cleaning
import os
import re

#import natural language toolkit
import nltk

# get lexicon we'll be working with today
nltk.download('vader_lexicon') 

## import word tokenizer
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Dillon\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # <font color='red'> Just a heads up I didnt add the imports from the webscrapping notebook idk if we're using them for this project.
#
#
# # <font color='red'> also thi mentioned something about how we cleaned up the question marks and odd symbols I'm not sure where to put that. I may have missed some imports from the sentiment analysis portion of the project too.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Combining the Datasets

# %%
#combining datasets into one dataframe
files = os.listdir('../Datasets')
allSchools = pd.DataFrame(columns = ['school', 'date', 'content'])
for i in files:
    if '.csv' in i:
        try:
            filepath = os.path.join('..','Datasets', i)
            frame = pd.read_csv(filepath)[['school', 'date', 'content']] 
            allSchools = pd.concat([allSchools, frame])
        except:
            print('Error with: '.ljust(30) + i)
            try:
                filepath = os.path.join('..','Datasets', i)
                frame = pd.read_csv(filepath, encoding='latin-1')[['school', 'date', 'content']]  
                allSchools = pd.concat([allSchools, frame])
                print(("Encoding to Latin **DID** Work for: ".ljust(30) + i))
            except:
                print(("Encoding DID **NOT** Work for: ".ljust(30) + i))
# Out:
# Error with:                   Florida_State_Univeristy.csv
# Encoding to Latin **DID** Work for: Florida_State_Univeristy.csv
# Error with:                   UC_Irvine.csv
# Encoding to Latin **DID** Work for: UC_Irvine.csv
# Error with:                   UC_Riverside.csv
# Encoding to Latin **DID** Work for: UC_Riverside.csv

# %%
#resetting the index of the dataframe
allSchools = allSchools.reset_index(drop = True)

# %%
#drop NA columns where we only had videos
allSchools = allSchools[~allSchools['content'].isna()]

# %%
#replacing \n with space
#then replaced any spaces in groups of 2 or more with just 1 space
#then split the content on space, and find its length
def word_count(string):
    cont = re.sub('\n{1,}', ' ', string)
    cont = re.sub(' {2,}', ' ', cont)
    return len(cont.split())

# %%
allSchools = allSchools.assign(word_count = allSchools['content'].apply(word_count))
allSchools.head(3)
# Out:
#                      school       date  \
# 0  Florida State University  28-Feb-20
# 1  Florida State University  28-Feb-20
# 2  Florida State University   2-Mar-20
#
#                                              content  word_count
# 0  Dear FSU Family,\n\nFlorida State University c...         615
# 1  This message to all faculty and staff has been...         175
# 2  The spring semester programs at Florida State ...         150

# %%
#separating schools by state
cal_schools = ["Berkeley","Davis","Irvine","Los Angeles","Merced","Riverside","Santa Barbara", "Santa Cruz", "Diego"]
tex_schools = ["Texas State University",  "Austin","Houston","University of North Texas", "T_A&M_U"]
fl_schools = ["Florida State University", "University of Central Florida", "Florida", "Miami","USF"]

# %%
#assigning states to each school
def give_state(string):
    if string in cal_schools:
        return 'cal'
    elif string in tex_schools:
        return 'tex'
    elif string in fl_schools:
        return 'fl'
    else:
        print('ERROR')
        return 'ERROR'

# %%
#implementing into dataframe
allSchools = allSchools.assign(state = allSchools['school'].apply(give_state))
allSchools.head(3)
# Out:
#                      school       date  \
# 0  Florida State University  28-Feb-20
# 1  Florida State University  28-Feb-20
# 2  Florida State University   2-Mar-20
#
#                                              content  word_count state
# 0  Dear FSU Family,\n\nFlorida State University c...         615    fl
# 1  This message to all faculty and staff has been...         175    fl
# 2  The spring semester programs at Florida State ...         150    fl

# %%
#Had to clean the year since it some didn't include the year, and some did '20' while others did '2020'
#Had to make sure all the years were abbreviated (converted the only case where it wasn't
def fix_year(string):
    string = string.replace('April', 'Apr') # the only case where it wasn't abbreviated
    if string[-4:] != '2020': #if it wasn't properly formatted
        if string[-2:] == '20': # still had some year, but not all
            return string+'20' #only add the last two digits
        else: # had no year data at all
            return string+'-2020' # add the entire year
    else:
        return string

# %%
# fixing the date format
allSchools = allSchools.assign(date = allSchools['date'].apply(fix_year))
# extracting the month from each
allSchools = allSchools.assign(month = pd.to_datetime(allSchools['date']).apply(lambda x: x.month))

# %%
allSchools = allSchools.reset_index(drop=True)

# %%
#converting to csv for rest of project
allSchools.to_csv('allSchools.csv', index = False)

# %% [markdown]
# # <font color=red>Thi mentioned something about a word count section to be included here.
#
# # <font color=red> Visualizations notebook here?

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### In the cells below our group attempted to determine a possible relationship between word counts in coronavirus annoucements and other variables such as time, in order to see if there was a significant difference between states' colleges.
#
# ### <font color = red> If we don't need this/have a better description please change. Also I think I got everything from the visualizations notebook but I may have missed some stuff I was pretty tired while making this

# %%
#adding a number of days past column to the dataset
allSchools = pd.read_csv('allSchools.csv')
allSchools = allSchools.assign(date = pd.to_datetime(allSchools['date']))
for i in ['Santa Barbara', 'Riverside', 'Merced', 'Santa Cruz']: 
    allSchools = allSchools[allSchools['school'] != i]
sort = allSchools.sort_values('date')

# %%
first_day = sort['date'].iloc[0]
sort['days_past'] = sort['date'].apply(lambda x: (x-first_day).days)

# %%
sort.head(3)
# Out:
#           school       date  \
# 606        Diego 2020-01-22
# 254       Irvine 2020-01-22
# 357  Los Angeles 2020-01-23
#
#                                                content  word_count state  \
# 606  Dear Students, UC San Diego Student Health Ser...         286   cal
# 254  ItÕs that time of year when many of us get run...         310   cal
# 357  To the UCLA Community, As we approach the peak...         318   cal
#
#      month  days_past
# 606      1          0
# 254      1          0
# 357      1          1

# %%
#compiling a cumulative total of word counts for all colleges column
sort['cum_sum_all'] = sort['word_count'].cumsum()
sort.head()
# Out:
#           school       date  \
# 606        Diego 2020-01-22
# 254       Irvine 2020-01-22
# 357  Los Angeles 2020-01-23
# 607        Diego 2020-01-23
# 680      Florida 2020-01-24
#
#                                                content  word_count state  \
# 606  Dear Students, UC San Diego Student Health Ser...         286   cal
# 254  ItÕs that time of year when many of us get run...         310   cal
# 357  To the UCLA Community, As we approach the peak...         318   cal
# 607  We are committed to keeping our campus communi...         502   cal
# 680  JANUARY 24: GUIDANCE ON COVID-19\r\nUniversity...          99    fl
#
#      month  days_past  cum_sum_all
# 606      1          0          286
# 254      1          0          596
# 357      1          1          914
# 607      1          1         1416
# 680      1          2         1515

# %%
#plotting cumulative word counts
fig, ax = plt.subplots(figsize =(15,10))
sort[sort['state'] == 'fl'].plot(x = 'days_past',y= 'cum_sum_all', kind = 'scatter', ax = ax)
sort[sort['state'] == 'cal'].plot(x = 'days_past',y= 'cum_sum_all', kind = 'scatter', ax = ax)
sort[sort['state'] == 'tex'].plot(x = 'days_past',y= 'cum_sum_all', kind = 'scatter', ax = ax)

# %% [markdown]
# # <font color = red> Description needed here, fyi we also have a png of this saved in our repo

# %%
#plotting announcements in a lineplot separated by date and state 
info = allSchools.groupby(["date","state"]).mean()
fig, ax = plt.subplots(figsize =(15,10))
info["word_count"].unstack().plot(ax=ax) 
ax.set(xlabel='Date', ylabel="Word Count")
# Out:
# [Text(0, 0.5, 'Word Count'), Text(0.5, 0, 'Date')]

# %% [markdown]
# # <font color = red> Description needed here,

# %%
#separating values by state
whole_df = pd.DataFrame()
for i in ['cal', 'tex', 'fl']:
    piece = sort[sort['state'] == i].copy()
    piece['cum_sum_state'] = sort[sort['state'] == i]['word_count'].cumsum()
    whole_df = pd.concat([piece, whole_df])

# %%
fig, ax = plt.subplots(figsize =(15,10))
whole_df[whole_df['state'] == 'fl'].plot(x = 'days_past',y= 'cum_sum_state', kind = 'scatter', ax = ax, color = 'purple')
whole_df[whole_df['state'] == 'cal'].plot(x = 'days_past',y= 'cum_sum_state', kind = 'scatter', ax = ax, color = 'blue')
whole_df[whole_df['state'] == 'tex'].plot(x = 'days_past',y= 'cum_sum_state', kind = 'scatter', ax = ax, color = 'red')
ax.set(xlabel='Days Since Start', ylabel="Word Count")
ax.legend(['Florida', 'California', 'Texas'])

# %% [markdown]
# # <font color =red> Description here

# %% [markdown]
# # <font color =red> The graph below was essentially the same as the graph above but we collapsed all the values with the same day I'm not sure if we need both plots

# %%
fig, ax = plt.subplots(figsize =(15,10))
whole_df = pd.DataFrame()
color = ['purple', 'blue', 'red']
j = 0
for i in ['fl', 'cal', 'tex']:
    piece = sort[sort['state'] == i].copy()
    piece = piece.groupby('days_past').mean()['word_count'].to_frame().reset_index()
    piece['cum_sum_state'] = piece['word_count'].cumsum()
    piece.plot(x = 'days_past', y = 'cum_sum_state' , kind = 'scatter', ax = ax, color = color[j])
    j+= 1
ax.set(xlabel='Days Since Start', ylabel="Word Count (meaned)")
ax.legend(['Florida', 'California', 'Texas'])

# %% [markdown]
# # <font color =red>Description here

# %%
#mean word count organized by days past 
piece = sort[sort['state'] == i].copy()
piece = piece.groupby('days_past').mean()['word_count'].to_frame().reset_index()
piece['cum_sum_state'] = piece['word_count'].cumsum()
piece
# Out:
#     days_past  word_count  cum_sum_state
# 0           5  565.000000     565.000000
# 1           6  339.000000     904.000000
# 2           8  197.000000    1101.000000
# 3          35  228.000000    1329.000000
# 4          37  410.333333    1739.333333
# ..        ...         ...            ...
# 69        122   15.000000   29022.758333
# 70        123  189.000000   29211.758333
# 71        124   74.000000   29285.758333
# 72        126  124.000000   29409.758333
# 73        129   40.000000   29449.758333
#
# [74 rows x 3 columns]

# %%
data = pd.read_csv("allSchools.csv")
cal_schools= data[data["state"]== "cal"].groupby(["month","school"]).sum()
fig, ax = plt.subplots(figsize =(15,10))
cal_schools["word_count"].unstack().plot(ax=ax)
ax.set_xticks([1,2,3,4,5])
ax.set(xlabel='Month', ylabel="Word Count")
# Out:
# [Text(0, 0.5, 'Word Count'), Text(0.5, 0, 'Month')]

# %% [markdown]
# # <font color=red> Description here

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# # <font color = red> The big ol sentiment analysis portion. We have a lot of stuff such as where we separated by state and the one where we did all schools and also the part where we looked for specific words, I'm not sure how to organize it all out tbh

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### Seting up the notebook and data for sentiment analysis

# %%
# To fix the lookup error produced by this cell
nltk.download('punkt')

# Provided code from lecture
allSchools['token'] = allSchools['content'].apply(word_tokenize) 

# To fix the lookup error produced by this cell
nltk.download('stopwords')

# import stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()

from nltk.probability import FreqDist
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dillon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dillon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Modifying the content column for sentiment analysis

# %%
# Cleaning up the 'content' column removing incidents of '\r', '\n', nad '\n\n'
allSchools['content'] = allSchools['content'].apply(lambda x: x.replace('\n',' ')) 
allSchools['content'] = allSchools['content'].apply(lambda x: x.replace('\r',' '))
allSchools['content'] = allSchools['content'].apply(lambda x: x.replace('\n\n',' '))

# %%
# remove stop words
allSchools['stop'] = allSchools['token'].apply(lambda x: [item for item in x if item not in stop_words])
allSchools.head()
# Out:
#                      school       date  \
# 0  Florida State University 2020-02-28
# 1  Florida State University 2020-02-28
# 2  Florida State University 2020-03-02
# 3  Florida State University 2020-03-03
# 4  Florida State University 2020-03-03
#
#                                              content  word_count state  month  \
# 0  Dear FSU Family,  Florida State University con...         615    fl      2
# 1  This message to all faculty and staff has been...         175    fl      2
# 2  The spring semester programs at Florida State ...         150    fl      3
# 3  Dear Faculty, Staff and Students,  I want to u...         256    fl      3
# 4  Florida State University is taking aggressive ...         448    fl      3
#
#                                                token  \
# 0  [Dear, FSU, Family, ,, Florida, State, Univers...
# 1  [This, message, to, all, faculty, and, staff, ...
# 2  [The, spring, semester, programs, at, Florida,...
# 3  [Dear, Faculty, ,, Staff, and, Students, ,, I,...
# 4  [Florida, State, University, is, taking, aggre...
#
#                                                 stop
# 0  [Dear, FSU, Family, ,, Florida, State, Univers...
# 1  [This, message, faculty, staff, approved, Kyle...
# 2  [The, spring, semester, programs, Florida, Sta...
# 3  [Dear, Faculty, ,, Staff, Students, ,, I, want...
# 4  [Florida, State, University, taking, aggressiv...

# %%
# remove stop words
allSchools['stop'] = allSchools['token'].apply(lambda x: [item for item in x if item not in stop_words])

# stemming
allSchools['stem'] = allSchools['stop'].apply(lambda x: [ps.stem(y) for y in x])

# get series of all words after stemming
stem_allSchools = allSchools['stem'].apply(pd.Series).stack()

# calculation word frequency
fdist_allSchools = FreqDist(stem_allSchools)


# remove punctuation counts
for punc in string.punctuation:
    del fdist_allSchools[punc]
    
# get list of the 'sentences' (responses) from each individual
allSchools_list = list(allSchools['content'].values)

# %% [markdown]
# ### Frequency distribution of the most common words across all messages

# %%
# for words in what students like most
fdist_allSchools.plot(20, cumulative=False)

# %% [markdown]
# ### Function to output dataframe storing sentiment information

# %%
# create function that will output dataframe 
# that stores sentiment information
def get_sentiments(input_list):
    
    output = pd.DataFrame()

    for sentence in input_list:
        ss = analyser.polarity_scores(sentence)
        ss['sentence'] = sentence
        output = output.append(ss, ignore_index=True)

    return output

# %% [markdown]
# ### Get the sentiment measures

# %%
analyser = SentimentIntensityAnalyzer()

# get sentiment measures
allSchools_sentiments = get_sentiments(allSchools_list)

allShools_sent = allSchools.drop(['token', 'stop'], axis = 1)\
.assign(pos = allSchools_sentiments['pos'])\
.assign(neg = allSchools_sentiments['neg'])\
.assign(neu = allSchools_sentiments['neu'])\
.assign(compound = allSchools_sentiments['compound'])

allShools_sent.to_csv('allShools_sent.csv', index = False)

#print the dataframe
allShools_sent.head()
# Out:
#                      school       date  \
# 0  Florida State University 2020-02-28
# 1  Florida State University 2020-02-28
# 2  Florida State University 2020-03-02
# 3  Florida State University 2020-03-03
# 4  Florida State University 2020-03-03
#
#                                              content  word_count state  month  \
# 0  Dear FSU Family,  Florida State University con...         615    fl      2
# 1  This message to all faculty and staff has been...         175    fl      2
# 2  The spring semester programs at Florida State ...         150    fl      3
# 3  Dear Faculty, Staff and Students,  I want to u...         256    fl      3
# 4  Florida State University is taking aggressive ...         448    fl      3
#
#                                                 stem    pos    neg    neu  \
# 0  [dear, fsu, famili, ,, florida, state, univers...  0.108  0.070  0.822
# 1  [thi, messag, faculti, staff, approv, kyle, cl...  0.054  0.027  0.919
# 2  [the, spring, semest, program, florida, state,...  0.030  0.025  0.946
# 3  [dear, faculti, ,, staff, student, ,, I, want,...  0.086  0.050  0.865
# 4  [florida, state, univers, take, aggress, step,...  0.086  0.117  0.797
#
#    compound
# 0    0.9751
# 1    0.5994
# 2    0.2023
# 3    0.8658
# 4   -0.9461

# %% [markdown]
# ### Function to filter the sentiments by a key word

# %%
def sort_df(word):
    new = allSchools[allSchools['content'].str.contains(word, case=False)]
    new = new.reset_index(drop = True)
    new_list = list(new['content'].values)
    new_sentiments = get_sentiments(new_list)
    
    new = new.drop(['token', 'stop'], axis = 1)
    new = new.assign(pos = new_sentiments['pos'])
    new = new.assign(neg = new_sentiments['neg'])
    new = new.assign(neu = new_sentiments['neu'])
    new = new.assign(compound = new_sentiments['compound'])
    
    return new

# %% [markdown]
# # <font color = red> Bryant could insert the plots here of the schools compound distributions

# %% [markdown]
# ### Filtering the sentiments by the word 'panic'

# %%
# Using the sort_df function to filter the dataframe for messages containing the word panic
df_panic = sort_df('panic')

# %% [markdown]
# ### Looking at the overall distribution of the compund score  for panic

# %%
df_panic['compound'].plot.hist()

# %% [markdown]
# ### Looking at the distribution of the compund score for 'panic' in California schools

# %%
sns.distplot(df_panic.loc[df_panic['state'] == 'cal']['compound'], kde = False, bins=25)

# %% [markdown]
# ### Looking at the distribution of the compund score for 'panic' in Texas schools

# %%
sns.distplot(df_panic.loc[df_panic['state'] == 'tex']['compound'], kde = False, bins=25)

# %% [markdown]
# ### Looking at the distribution of the compund score for 'panic' in Florida schools

# %%
sns.distplot(df_panic.loc[df_panic['state'] == 'fl']['compound'], kde = False, bins=25)

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# # <font color = red> discussion about this section here may be needed

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# # <font color=red>For the discussion this is where we can talk about the limitations of whichever school has the more wordy messages and whether thats bc theyre actually responding heavily to corona or if theyre jus a piece of shit overwriting all their messages in general and more

# %% [markdown]
# # Team Contributions

# %% [markdown]
# *Specify who in your group worked on which parts of the project.*
