# %% [markdown]
# ## Final Report
# ### Imports

# %%
# Imports

# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import statsmodels.api as sm
import os 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading in the UC School csv files

# %%
# Read in Berekeley
df_ucb = pd.read_csv(os.path.join('Datasets', 'UC_Berkeley.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Read in Davis
df_ucd = pd.read_csv(os.path.join('Datasets', 'UC_Davis.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'text':'str', 'school':'str'})

# Read in Irvine
#df_uci = pd.read_csv(os.path.join('Datasets', 'UC_Irvine.csv'), 
#                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Read in Los Angeles
df_ucla = pd.read_csv(os.path.join('Datasets', 'UC_Los_Angeles.csv'), 
                      dtype={'date': 'str', 'word_count':int, 'content':'str', 'school':'str'})

# Read in Merced
df_ucm = pd.read_csv(os.path.join('Datasets', 'UC_Merced.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'content':'str', 'school':'str'})

# Read in Riverside
#df_ucr = pd.read_csv(os.path.join('Datasets', 'UC_Riverside.csv'), 
#                     dtype={'date': 'str', 'word_count':'str', 'school':'str'})

# Read in San Diego
df_ucsd = pd.read_csv(os.path.join('Datasets', 'UC_San_Diego.csv'), 
                      dtype={'date': 'str', 'word_count':'int','content':'str', 'school':'str'})

# Read in Santa Barbra
df_ucsb = pd.read_csv(os.path.join('Datasets', 'UC_Santa_Barbara.csv'),
                      dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Read in Santa Cruz
df_ucsc = pd.read_csv(os.path.join('Datasets', 'UC_Santa_Cruz.csv'), 
                      dtype={'date': 'str', 'word_count':int, 'content':'str', 'school':'str'})

# %% [markdown]
# ### Take a look at UC Berkeley

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucb['state'] = 'CA'

# Dropping the 'link' column associated with each update
df_ucb = df_ucb.drop(['link'], axis =1)

# Reordering the columns into a more readable format
df_ucb = df_ucb[['date','school','state','content','word_count']]


df_ucb.head()
# Out:
#         date    school state  \
# 0  18-May-20  Berkeley    CA
# 1  16-May-20  Berkeley    CA
# 2  14-May-20  Berkeley    CA
# 3  12-May-20  Berkeley    CA
# 4  12-May-20  Berkeley    CA
#
#                                              content  word_count
# 0  We are writing today to share news about budge...         397
# 1  Members of the remarkable and resilient gradua...        1368
# 2  A simulated Commencement 2020 will take place ...        2291
# 3  Last Tuesday, our campus participated in #Givi...         887
# 4  There are two major budget concerns Chancellor...         354

# %% [markdown]
# ### Take a look at UC Davis

# %%
# Renaming text column to content
df_ucd = df_ucd.rename(columns = {'text':'content'})

# Adding a 'state' column and setting its default value to 'CA'
df_ucd['state'] = 'CA'

# Reordering the columns into a more readable format
df_ucd = df_ucd[['date','school','state','content']]

df_ucd.head()
# Out:
#         date school state                                            content
# 0  31-Jan-20  Davis    CA  Fight it like the flu\nUpdated 5 p.m. Jan. 31 ...
# 1   1-Feb-20  Davis    CA  Yolo County info page\nYolo County, in which t...
# 2   3-Feb-20  Davis    CA  Screening at airports\nUpdated 9 p.m. Feb. 3  ...
# 3   7-Feb-20  Davis    CA  No reports of coronavirus\nUpdated 11:30 a.m. ...
# 4  10-Feb-20  Davis    CA  UC Davis Live\nUpdated Feb. 10 Watch UC Davis ...

# %% [markdown]
# ### Take a look at UC Irvine

# %%
# Take a look at Irvine
#df_uci['state'] = 'CA'
#df_uci.head()

# %% [markdown]
# ### Take a look at UC Los Angeles

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucla['state'] = 'CA'

# Reordering the columns into a more readable format
df_ucla = df_ucla[['date','school','state','content', 'word_count']]

df_ucla.head()
# Out:
#         date       school state  \
# 0  23-Jan-20  Los Angeles    CA
# 1  31-Jan-20  Los Angeles    CA
# 2   4-Feb-20  Los Angeles    CA
# 3  20-Feb-20  Los Angeles    CA
# 4  27-Feb-20  Los Angeles    CA
#
#                                              content  word_count
# 0  To the UCLA Community, As we approach the peak...         318
# 1  To the Campus Community, As news coverage of t...         434
# 2  Dear Colleagues: UCLA has developed a review a...         402
# 3  Dear Bruins: I am writing to advise on interna...         370
# 4  Warning Level 3: Avoid all non-essential trave...         220

# %% [markdown]
# ### Take a look at UC Merced

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucm['state'] = 'CA'

# Reordering the columns into a more readable format
df_ucm = df_ucm[['date','school','state','content', 'word_count']]

df_ucm.head()
# Out:
#         date  school state                                            content  \
# 0   4-Feb-20  Merced    CA  Coronavirus Update\r\nFebruary 4, 2020\r\nInfo...
# 1  28-Feb-20  Merced    CA  UPDATE: What You Need to Know About COVID-19\r...
# 2   6-Mar-20  Merced    CA  COVID-19: Protect Yourself and Each Other\r\nM...
# 3   8-Mar-20  Merced    CA  COVID-19: University Travel Guidance\r\nMarch ...
# 4   9-Mar-20  Merced    CA  COVID-19 Instructional Continuity\r\nMarch 9, ...
#
#    word_count
# 0         190
# 1         457
# 2         468
# 3         411
# 4         489

# %% [markdown]
# ### Take a look at UC Riverside

# %%
# Adding a 'state' column and setting its default value to 'CA'
#df_ucr['state'] = 'CA'
#df_ucr.head()

# %% [markdown]
# ### Take a look at UC San Diego

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucsd['state'] = 'CA'

# Reordering the columns into a more readable format
df_ucsd = df_ucsd[['date','school','state','content', 'word_count']]

# Printing dataframe so we can view all entries
print(df_ucsd.to_string()) # You will notice NaNs at the bottom of the data frame
# Out:
#          date school state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 0   22-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 1   23-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 2   27-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 3   30-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 4   30-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 5   31-Jan-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                UC San Diego continues to be vigilant in monitoring the progression of the 2019 Novel Coronavirus (2019-nCoV) worldwide. Despite the declaration by the World Health Organization of a public health emergency of international concern, it is important to note that there are no known confirmed cases of 2019-nCoV in San Diego at this time. However, as the numbers of cases has continued to expand and both the U.S. Centers for Disease Control and Prevention (CDC) and the State Department have warned against non-essential travel to China, the University of California has called for a temporary stop of non-essential travel to the affected region. We are developing a review and approval process to determine which travel to China is essential and if postponing is an option. We understand that members of the community are worried about the virus and how it may impact us. Rest assured, your health and wellbeing is our top priority. Our goal is to keep you informed and to provide a safe campus environment for all students, employees and visitors. Our leadership and health care experts are in continuous contact with the CDC, the California Department of Public Health, and San Diego County Public Health for updated information on the outbreak. We are making adjustments to the protocols to screen, identify and diagnose potential cases of 2019-nCoV. If cases occur, UC San Diego will collaborate with the CDC and San Diego Public Health to prevent, isolate, and control the spread of this infection. The CDC has expanded the area of travel concern to encompass Hubei Provence and created a framework to identify and isolate patients meeting criteria for 2019-nCoV testing. The criteria is based on the highest to lowest probability of infection, ranging from those who have been in close contact with a patient with a laboratory confirmed diagnosis of 2019-nCoV, to patients who are experiencing fever and cough and those who have traveled to the province of Hubei within 14 days of symptom onset. Persons who have traveled to mainland China within the past 14 days should self-monitor for symptoms of acute respiratory infection including fever and cough or other flu-like symptoms. If you have these symptoms and travel history within the past 14 days, please contact Student Health or your healthcare provider. Until you have a medical evaluation, take precautionary steps to reduce possible exposure to others by covering your cough and sneezes, washing your hands frequently and avoiding close contact (less than 6 feet or 2 meters) with other people. This Q&A may provide helpful information about 2019-nCoV. Q Is 2019-nCoV spreading in the U.S? A While the number of cases in the U.S. has risen, most cases continue to be patients who contracted the virus during a visit to impacted regions in C ...
# 6    3-Feb-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 7    5-Feb-20  Diego    CA                                                                                                                                                                                                                                                                                                                        UC San Diego continues to be vigilant in monitoring the progression of the 2019 Novel Coronavirus (2019-nCoV) and is responding as additional information becomes available. Despite the declaration by the World Health Organization of a public health emergency of international concern, it is important to note that there are no known confirmed cases of 2019-nCoV in San Diego at this time. Our leadership and health care experts are in continuous contact with the CDC, the California Department of Public Health, and San Diego County Public Health for updated information on the outbreak. Please join us Thursday, Feb. 6 from 5 to 5:45 p.m. for the campus’ second webinar featuring UC San Diego’s health experts who will share the latest advice from these local, national and international health agencies regarding the ongoing situation with the 2019 Novel Coronavirus (2019-nCoV). Francesca Torriani, M.D., UC San Diego Health's Program Director of Infection Prevention and Hospital Epidemiology and an Infectious Diseases specialist, and Stacie San Miguel, M.D., Director of Medical Services for UC San Diego Student Health Services, will share their expertise, and recommendations on preventative measures. In addition, they will relay UC San Diego’s plan to identify, treat and contain any potential cases of 2019-nCoV diagnosed within the UC San Diego community. Drs. Torriani and San Miguel will be joined by Alysson Satterlund, Vice Chancellor for Student Affairs who will be a part of the question and answer section of the webinar to address student queries and concerns. All faculty, students, and staff are encouraged to participate. See details below: UC San Diego Novel Coronavirus Zoom Webinar https://uchealth.zoom.us/j/353087224 Webinar ID: 353 087 224 To call in: US: +1 669 900 6833 or +1 646 876 9923 International numbers available: https://uchealth.zoom.us/u/aBr5ob91P For those unable to participate in the webinar, it will be archived online on Blink at https://blink.ucsd.edu/safety/resources/public-health/coronavirus.html. TRAVEL UPDATE: With increasing concern about global spread of the nCoV, the U.S. State Department has issued a Level 4 travel advisory (https://bit.ly/2Op1GD4) related to travel to and from China. Under this advisory, all non-essential travel to China by U.S. Government personnel has been suspended. President Napolitano has directed that the UC community temporarily avoid all non-essential travel to China. Each UC campus and medical center has been directed to develop a process to determine if travel to China is essential or can be postponed. UC San Diego’s interim policy is consistent with this policy and can be found at http://adminrecords.ucsd.edu/Notices/2020/2020-2-3-3.html. It is not intended to be a travel ban since UC San Diego faculty, staff and students may have legitimate reasons to travel to China for essential purposes and/or personal emergencies. Travelers should practice easy health precautions, including avoiding close contact with people who are visibly sick, practicing excellent hand hygiene and covering coughs and sneezes. The CDC has expanded the area of travel concern to encompass mainland China and created a framework to identify and isolate patients meeting criteria for 2019-nCoV testing Patients Under Investigation (PUI). The criteria are based on the highest to lowest probability of infection, ranging from those who have been in close contact with a patient with a laboratory confirmed diagnosis of 2019-nCoV and who are experiencing fever or cough to those who have traveled to China within 14 days of symptom onset and who are experiencing fever and cough or short ...
# 8   14-Feb-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 9   26-Feb-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# ...
# 43   9-Apr-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 44  20-Apr-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 45  28-Apr-20  Diego    CA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Universities around the world are making critical decisions for the coming academic year during the evolving public health crisis of COVID-19. UC San Diego is making plans for the fall quarter based up ...

# %%
# Dropping the empty rows at the bottom of df_ucsd
df_ucsd = df_ucsd.dropna()

# Now that the 4 rows with missing data on the bottom with the NaN values have been removed 
# We can convert word_count column back into an integer
convert_dict = {'word_count': int}
df_ucsd = df_ucsd.astype(convert_dict)

df_ucsd.head()
# Out:
#         date school state                                            content  \
# 0  22-Jan-20  Diego    CA  Dear Students, UC San Diego Student Health Ser...
# 1  23-Jan-20  Diego    CA  We are committed to keeping our campus communi...
# 2  27-Jan-20  Diego    CA  UC San Diego continues to be vigilant in monit...
# 3  30-Jan-20  Diego    CA  Dear Colleagues As you know, UC is closely mon...
# 4  30-Jan-20  Diego    CA  On Thursday, Jan. 30 from 430 p.m. to 515 p.m....
#
#    word_count
# 0         285
# 1         507
# 2         807
# 3         280
# 4         873

# %% [markdown]
# ### Take a look at UC Santa Barbara

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucsb['state'] = 'CA'
df_ucsb = df_ucsb.drop(['link'], axis =1)

# Reordering the columns into a more readable format
df_ucsb = df_ucsb[['date','school','state','content', 'word_count']]

df_ucsb.head()
# Out:
#         date         school state  \
# 0  14-May-20  Santa Barbara    CA
# 1  18-Apr-20  Santa Barbara    CA
# 2  13-Apr-20  Santa Barbara    CA
# 3  07-Apr-20  Santa Barbara    CA
# 4  02-Apr-20  Santa Barbara    CA
#
#                                              content  word_count
# 0  Dear Members of Our Campus Community,\r\n\r\nI...        1546
# 1  Dear Members of Our Campus Community,\r\n\r\nW...         498
# 2  Dear Members of Our Campus Community,\r\n\r\nW...         395
# 3  Dear Members of Our Campus Community,\r\n\r\nI...         484
# 4  Dear Members of Our Campus Community,\r\n\r\nI...          74

# %% [markdown]
# ### Take a look at Santa Cruz

# %%
# Adding a 'state' column and setting its default value to 'CA'
df_ucsc['state'] = 'CA'

# Reordering the columns into a more readable format
df_ucsc = df_ucsc[['date','school','state','content', 'word_count']]

df_ucsc.head()
# Out:
#         date      school state  \
# 0  24-Jan-20  Santa Cruz    CA
# 1  30-Jan-20  Santa Cruz    CA
# 2  31-Jan-20  Santa Cruz    CA
# 3   4-Feb-20  Santa Cruz    CA
# 4   4-Feb-20  Santa Cruz    CA
#
#                                              content  word_count
# 0  The UC Santa Cruz Student Health Center offers...         414
# 1  UC Santa Cruz health officials are closely mon...         382
# 2  Due to the dynamic situation with the coronavi...         338
# 3  The UC Office of the President has directed th...        1276
# 4  To: UC Santa Cruz Community\r\nFrom: Public Af...         989

# %% [markdown]
# ### Combining all of our UC data frames

# %%
# concatenating the dataframes together
df_ca = pd.concat([df_ucsc, df_ucm, df_ucd, df_ucb, df_ucsd, df_ucsb, df_ucla], sort= True)

# ordering columns
df_ca = df_ca[['date','school','state','content', 'word_count']]

# replacing any incidents of '\r' and '\n' 
df_ca = df_ca.replace(r'\n',' ', regex=True) 
df_ca = df_ca.replace(r'\r',' ', regex=True) 

df_ca.content = df_ca.content.astype('str')

# looking at the entire dataframe
print(df_ca.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Reading in Texas school csv files

# %%
pd.read_csv(os.path.join('Datasets', 'Texas_State_University.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})
# Out:
#          date                                            content  \
# 0   30-Jan-20   In response to the Novel Coronavirus outbreak...
# 1   26-Feb-20   Over the past several weeks, Texas State Univ...
# 2   28-Feb-20   Over the past several weeks, Texas State Univ...
# 3    2-Mar-20  Dear Texas State Community,\n\nAs news continu...
# 4    5-Mar-20   The City of San Marcos in coordination with H...
# 5    6-Mar-20  \nDear University Community,\n\n As new cases ...
# 6    9-Mar-20  Dear Texas State Community,\n\n In response to...
# 7   12-Mar-20  Dear Students, Faculty, and Staff,\n\nI  have ...
# 8   16-Mar-20  Pandemic and Post-Pandemic Work Groups\nMay 18...
# 9   16-Mar-20  COVID-19 FAQs Updated \n\n As the COVID-19 sit...
# 10  18-Mar-20  Dear Texas State Community,\n\n COVID-19 conti...
# 11  19-Mar-20  Dear Students, Faculty, and Staff,\n\n This is...
# 12  23-Mar-20  \nDear Colleagues,\n\nEvery day, the circumsta...
# 13  24-Mar-20  In  order to best serve the interest of public...
# 14  25-Mar-20  Texas  State University remains open to provid...
# 15  26-Mar-20   Last night,  Hays County joined Williamson, T...
# 16  26-Mar-20  Dear Students, \n\n Hays County Judge Ruben Be...
# 17  26-Mar-20   Dear Colleagues,\n \n As we prepare to welcom...
# 18  27-Mar-20  In  response to the evolving COVID-19 pandemic...
# 19  27-Mar-20  Governor Greg Abbott signed a state disaster d...
# 20  27-Mar-20  This is a challenging time for everyone and ce...
# 21  27-Mar-20  Dear Students,\n\nMonday begins a new journey ...
# 22  27-Mar-20  Dear Colleagues,\n\nIn the midst of this incre...
# 23  27-Mar-20  \n Today, the university learned that a  facul...
# 24  27-Mar-20  Bobcats, we know you are excited to register f...
# 25  31-Mar-20  As part of  the transition to remote instructi...
# 26   1-Apr-20  Laboratory-based  science is an important comp...
# 27   1-Apr-20  I  hope everyone is doing well and adapting to...
# 28   3-Apr-20  Let me begin by  acknowledging the tremendous ...
# 29   3-Apr-20  Dear Faculty, Staff and Students, \n\nToday th...
# 30   8-Apr-20  Dear Round Rock Students, \n\n You may be awar...
# 31   8-Apr-20   VocaLibre is an auditioned group of Texas Sta...
# 32   9-Apr-20  The Counseling Center has developed a Webinar ...
# 33  10-Apr-20  As we end our second week of remote instructio...
# 34  17-Apr-20  Texas State University staff, faculty, and und...
# 35  17-Apr-20   As we close the third week of remote instruct...
# 36  23-Apr-20  Faculty and Staff,\n\n While social distancing...
# 37  23-Apr-20   Texas State University announces the Bobcat C...
# 38  24-Apr-20  As we close the fourth week of remote instruct...
# 39  30-Apr-20   Although some shelter-in-place orders are exp...
# 40   1-May-20   In preparation to resume in-person teaching f...
# 41   1-May-20  \nAs we close the fifth week of remote instruc...
# 42   1-May-20   The Texas State University Systems seven memb...
# 43   9-May-20   As we end the sixth week of remote instructio...
# 44  11-May-20  Dear Bobcats,\n\n When the decision was made t...
# 45  18-May-20  \nDear Texas State University Community,\n\n I...
#
#                     school
# 0   Texas State University
# 1   Texas State University
# 2   Texas State University
# 3   Texas State University
# 4   Texas State University
# 5   Texas State University
# 6   Texas State University
# 7   Texas State University
# 8   Texas State University
# 9   Texas State University
# 10  Texas State University
# 11  Texas State University
# 12  Texas State University
# 13  Texas State University
# 14  Texas State University
# 15  Texas State University
# 16  Texas State University
# 17  Texas State University
# 18  Texas State University
# 19  Texas State University
# 20  Texas State University
# 21  Texas State University
# 22  Texas State University
# 23  Texas State University
# 24  Texas State University
# 25  Texas State University
# 26  Texas State University
# 27  Texas State University
# 28  Texas State University
# 29  Texas State University
# 30  Texas State University
# 31  Texas State University
# 32  Texas State University
# 33  Texas State University
# 34  Texas State University
# 35  Texas State University
# 36  Texas State University
# 37  Texas State University
# 38  Texas State University
# 39  Texas State University
# 40  Texas State University
# 41  Texas State University
# 42  Texas State University
# 43  Texas State University
# 44  Texas State University
# 45  Texas State University

# %%
# Read in Texas State University (UNICODEDECODE ERRROR)
df_tsu = pd.read_csv(os.path.join('Datasets', 'Texas_State_University.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Read in University Austin Texas
df_uat = pd.read_csv(os.path.join('Datasets', 'University_Austin_Texas.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Read in Texas A&M University
df_utm = pd.read_csv(os.path.join('Datasets', 'U_T&M.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})


# Read in University North Texas
df_unt = pd.read_csv(os.path.join('Datasets', 'UNT.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Reading in University of Houston
df_uh = pd.read_csv(os.path.join('Datasets', 'University_Houston.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# %% [markdown]
# ## Take a look at Texas State University

# %%
# Renaming message column to content
df_tsu = df_tsu.rename(columns = {'message':'content'})

# Adding a 'state' column and setting its default value to 'TX'
df_tsu['state'] = 'TX'

# Reordering the columns into a more readable format
df_tsu = df_tsu[['date','school','state','content']]

df_tsu.head()
# Out:
#         date                  school state  \
# 0  30-Jan-20  Texas State University    TX
# 1  26-Feb-20  Texas State University    TX
# 2  28-Feb-20  Texas State University    TX
# 3   2-Mar-20  Texas State University    TX
# 4   5-Mar-20  Texas State University    TX
#
#                                              content
# 0   In response to the Novel Coronavirus outbreak...
# 1   Over the past several weeks, Texas State Univ...
# 2   Over the past several weeks, Texas State Univ...
# 3  Dear Texas State Community,\n\nAs news continu...
# 4   The City of San Marcos in coordination with H...

# %% [markdown]
# ## Take a look at University of Austin Texas

# %%
# Renaming text column to content
df_uat = df_uat.rename(columns = {'text':'content'})

# Adding a 'state' column and setting its default value to 'TX'
df_uat['state'] = 'TX'

# Reordering the columns into a more readable format
df_uat = df_uat[['date','school','state','content']]

df_uat.head()
# Out:
#         date  school state                                            content
# 0  12-May-20  Austin    TX  Admissions has suspended campus visits, Admiss...
# 1  13-May-20  Austin    TX  COVID-19 Identified within UT Community - from...
# 2  15-May-20  Austin    TX  Through March 30, students are on spring break...
# 3  16-May-20  Austin    TX  Starting March 16, 2020, all campus buildings ...
# 4  17-May-20  Austin    TX  Starting March 16, 2020, all campus buildings ...

# %% [markdown]
# ## Take a look at Texas A&M University

# %%
# Renaming text column to content
df_utm = df_utm.rename(columns = {'text':'content'})

# Adding a 'state' column and setting its default value to 'TX'
df_utm['state'] = 'TX'

# Reordering the columns into a more readable format
df_utm = df_utm[['date','school','state','content']]

df_utm.head()
# Out:
#         date   school state                                            content
# 0  28-Feb-20  T_A&M_U    TX  February 28, 2020, 5:45 p.m. CST Dear Texas A&...
# 1   2-Mar-20  T_A&M_U    TX  March 2, 2020, 7:55 p.m. CST Texas A&M Univers...
# 2   3-Mar-20  T_A&M_U    TX  March 3, 2020, 5:45 p.m. CST Texas A&M continu...
# 3   6-Mar-20  T_A&M_U    TX  March 6, 2020, 4:30 p.m. CST Students, faculty...
# 4   9-Mar-20  T_A&M_U    TX  March 9, 2020, 5:00 p.m. CDT Texas A&M Cancels...

# %% [markdown]
# ## Take a look at University of North Texas

# %%
# Adding a 'state' column and setting its default value to 'TX'
df_unt['state'] = 'TX'

# Dropping the 'link' column associated with each update
df_unt = df_unt.drop(['link'], axis =1) 

# Reordering the columns into a more readable format
df_unt = df_unt[['date','school','state','content']]

df_unt.head()
# Out:
#           date                     school state  \
# 0  18-May-2020  University of North Texas    TX
# 1  15-May-2020  University of North Texas    TX
# 2  13-May-2020  University of North Texas    TX
# 3  11-May-2020  University of North Texas    TX
# 4  11-May-2020  University of North Texas    TX
#
#                                              content
# 0  Dear UNT community,\r\n\r\nDenton County Publi...
# 1  Final COVID-19 Regular Update\r\n\r\nToday’s e...
# 2  In an effort to keep our community as healthy ...
# 3  Have you been wearing a cloth face cover? Acco...
# 4  Dear UNT undergraduate students,\r\n\r\nWe hop...

# %% [markdown]
# ## Take a look at University of Houston

# %%
# Adding a 'state' column and setting its default value to 'TX'
df_uh['state'] = 'TX'

# Dropping the empty rows at the bottom of df_uh
df_uh = df_uh.dropna()

# Renamine the columns to match other Texas data frames
df_uh.columns = ['date', 'content', 'school', 'state']

# Reordering the columns into a more readable format
df_uh = df_uh[['date','school','state','content']]

df_uh.head()
# Out:
#      date   school state                                            content
# 0  27-Jan  Houston    TX  Dear Faculty, Students and Staff,\r\n\r\nThe U...
# 1  28-Jan  Houston    TX  Dear Faculty, Students and Staff,\r\n\r\nAt th...
# 2   2-Mar  Houston    TX  Dear Students, Faculty and Staff,\r\n\r\nThe U...
# 3   4-Mar  Houston    TX  UHS Faculty, Staff and Students,\r\n\r\nWe con...
# 4   6-Mar  Houston    TX  Dear Faculty:\r\n\r\nThere are now five confir...

# %% [markdown]
# ## Combining all of our Texas dataframes

# %%
# concatenating the dataframes together
df_tx = pd.concat([df_tsu, df_uat, df_utm, df_unt, df_uh], sort= True)
df_tx = df_tx[['date','school','state','content']]

# replacing any incidents of '\r' and '\n' 
df_tx = df_tx.replace(r'\n',' ', regex=True) 
df_tx = df_tx.replace(r'\r',' ', regex=True) 

# looking at the entire dataframe
print(df_tx.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Reading in Florida csv files

# %%
# Reading in Florida State University (UNICODE ERROR)
#df_fsu = pd.read_csv(os.path.join('Datasets', 'Florida_State_Univeristy.csv'), 
#                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Reading in University of Central Florida
df_ucf = pd.read_csv(os.path.join('Datasets', 'UCF.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Reading in Universirty of Florida
df_uf = pd.read_csv(os.path.join('Datasets', 'University_Florida.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Reading in University South Florida
df_usf = pd.read_csv(os.path.join('Datasets', 'USoFlorida.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# Reading in University of Miami
df_um = pd.read_csv(os.path.join('Datasets', 'University_Miami.csv'), 
                     dtype={'date': 'str', 'word_count':int, 'school':'str'})

# %% [markdown]
# ## Take a look at Florida State University

# %%
#df_fsu

# %% [markdown]
# ## Take a look at University of Central Florida

# %%
# Adding a 'state' column and setting its default value to 'TX'
df_ucf['state'] = 'FL'

# Dropping the 'link' column associated with each update
df_ucf = df_ucf.drop(['link'], axis =1) 

# Reordering the columns into a more readable format
df_ucf = df_ucf[['date','school','state','content']]

df_ucf.head()
# Out:
#           date                         school state  \
# 0  21-May-2020  University of Central Florida    FL
# 1  20-May-2020  University of Central Florida    FL
# 2  13-May-2020  University of Central Florida    FL
# 3  13-May-2020  University of Central Florida    FL
# 4  11-May-2020  University of Central Florida    FL
#
#                                              content
# 0  As we are all adjusting to the different reali...
# 1  COVID-19 has impacted all of us in some way. T...
# 2  As businesses and other entities across the st...
# 3  We would like to thank you for your continued ...
# 4  To continue to support our Knights during this...

# %% [markdown]
# ## Take a look at University of Florida

# %%
# Renaming text column to content
df_uf = df_uf.rename(columns = {'text':'content'})

# Adding a 'state' column and setting its default value to 'TX'
df_uf['state'] = 'FL'

# Reordering the columns into a more readable format
df_uf = df_uf[['date','school','state','content']]

df_uf.head()
# Out:
#         date   school state                                            content
# 0  24-Jan-20  Florida    FL  JANUARY 24: GUIDANCE ON COVID-19\r\nUniversity...
# 1  31-Jan-20  Florida    FL  JANUARY 31: GUIDANCE ON COVID-19\r\nWith the W...
# 2  10-Feb-20  Florida    FL  FEBRUARY 10: GUIDANCE ON COVID-19\r\nAs the ou...
# 3  11-Feb-20  Florida    FL  FEBRUARY 11: GUIDANCE ON COVID-19\r\nTravelers...
# 4  28-Feb-20  Florida    FL  FEBRUARY 28: GUIDANCE ON COVID-19\r\nAs cases ...

# %% [markdown]
# ## Take a look at University of South Florida

# %%
# Renaming text column to content
df_usf = df_usf.rename(columns = {'text':'content'})

# Adding a 'state' column and setting its default value to 'TX'
df_usf['state'] = 'FL'

# Reordering the columns into a more readable format
df_usf = df_usf[['date','school','state','content', 'word_count']]

df_usf.head()
# Out:
#         date school state                                            content  \
# 0  27-Jan-20    USF    FL  JANUARY 27, 2020COMMUNITY Dear USF students, f...
# 1  31-Jan-20    USF    FL  JANUARY 31, 2020COMMUNITY Dear USF community, ...
# 2  28-Feb-20    USF    FL  FEBRUARY 28, 2020COMMUNITY Dear USF community,...
# 3   2-Mar-20    USF    FL  Dear USF community, The University of South Fl...
# 4  11-Mar-20    USF    FL  MARCH 11, 2020COMMUNITY, FACULTY, STAFF, STUDE...
#
#    word_count
# 0         503
# 1         471
# 2         901
# 3         544
# 4         787

# %% [markdown]
# ## Take a look at University of Miami

# %%
# Adding a 'state' column and setting its default value to 'TX'
df_um['state'] = 'FL'

# Dropping the empty rows at the bottom of df_um
df_um = df_um.dropna()

# Renamine the columns to match other Texas data frames
df_um.columns = ['date', 'content', 'school', 'state']

# Reordering the columns into a more readable format
df_um = df_um[['date','school','state','content']]

df_um.head()
# Out:
#         date school state                                            content
# 0  27-Jan-20  Miami    FL  Health Advisory: Novel Coronavirus (2019-nCoV)...
# 1  31-Jan-20  Miami    FL  To the University of Miami Community,\r\n\r\nW...
# 2  26-Feb-20  Miami    FL  To the University of Miami Community,\r\n\r\nF...
# 3  28-Feb-20  Miami    FL  To the University of Miami Community,\r\n\r\nT...
# 4  05-Mar-20  Miami    FL  Dear Faculty:\r\n\r\nAs we prepare for spring ...

# %% [markdown]
# ## Combining all of our Florida  dataframes

# %%
# concatenating the dataframes together
df_fl = pd.concat([df_ucf, df_uf,df_usf, df_um], sort= True)
df_fl = df_fl[['date','school','state','content', 'word_count']]

# replacing any incidents of '\r' and '\n' 
df_fl = df_fl.replace(r'\n',' ', regex=True) 
df_fl = df_fl.replace(r'\r',' ', regex=True) 
# looking at the entire dataframe
print(df_tx.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Sentiment Analysis

# %%
#import natural language toolkit
import nltk

# get lexicon we'll be working with today
nltk.download('vader_lexicon') 

## import word tokenizer
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Bryant
# [nltk_data]     Tran\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Let's start with the UC schools

# %% [markdown]
# #### Tokenization

# %%
# To fix the lookup error produced by this cell
nltk.download('punkt')

# Provided code from lecture
df_ca['token'] = df_ca['content'].apply(word_tokenize) 

df_ca.head()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Bryant
# [nltk_data]     Tran\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#         date      school state  \
# 0  24-Jan-20  Santa Cruz    CA
# 1  30-Jan-20  Santa Cruz    CA
# 2  31-Jan-20  Santa Cruz    CA
# 3   4-Feb-20  Santa Cruz    CA
# 4   4-Feb-20  Santa Cruz    CA
#
#                                              content  word_count  \
# 0  The UC Santa Cruz Student Health Center offers...       414.0
# 1  UC Santa Cruz health officials are closely mon...       382.0
# 2  Due to the dynamic situation with the coronavi...       338.0
# 3  The UC Office of the President has directed th...      1276.0
# 4  To: UC Santa Cruz Community  From: Public Affa...       989.0
#
#                                                token
# 0  [The, UC, Santa, Cruz, Student, Health, Center...
# 1  [UC, Santa, Cruz, health, officials, are, clos...
# 2  [Due, to, the, dynamic, situation, with, the, ...
# 3  [The, UC, Office, of, the, President, has, dir...
# 4  [To, :, UC, Santa, Cruz, Community, From, :, P...

# %% [markdown]
# #### Stop words

# %%
# To fix the lookup error produced by this cell
nltk.download('stopwords')

# import stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# look at stop words
print(stop_words)
# Out:
# {'both', 'needn', 'i', 'myself', 'itself', 'the', 'their', 'just', "you'll", 'through', 'is', 'about', 'any', 'at', 'once', 'more', 'have', "hadn't", 'as', 'after', 'ours', 'but', 'if', "haven't", 'there', 'themselves', "mustn't", "shouldn't", 'mustn', 'under', 'will', 'weren', 'she', 'been', 'because', 'why', "you've", 'nor', 'other', 'against', 'these', 'yours', "needn't", 'don', 'doesn', 'his', 's', 'again', 'few', "isn't", 'up', 'theirs', 'each', "you're", 'it', 'such', 'himself', 'was', 'only', 'are', 'here', 'herself', 'in', 'this', 'o', 'too', 'a', "she's", 'wasn', 'yourself', 'which', 'off', 'hadn', 're', 'had', 'me', 'couldn', 'aren', 'ourselves', 'between', 've', 'over', 'by', 'those', 'doing', 'most', 'my', 'who', 'an', 'did', 'he', 'm', 'then', 'than', 'shouldn', 'from', 'so', 'ma', 'him', 'until', 'didn', 'her', 'does', 'or', 'd', "didn't", 'out', 'them', 'll', 'we', 'haven', "don't", "doesn't", 'its', 'with', 'you', 'be', 't', "shan't", 'into', 'on', 'they', 'when', "won't", 'below', 'that', 'very', 'our', 'mightn', "wouldn't", 'am', 'hasn', 'isn', 'how', 'before', 'further', "should've", 'being', 'of', 'own', 'shan', 'what', 'to', 'can', 'some', 'for', 'not', 'where', 'your', 'now', 'during', 'do', 'all', 'won', 'should', 'wouldn', "it's", "aren't", "couldn't", "you'd", 'ain', 'has', "hasn't", "weren't", 'were', 'down', 'having', "wasn't", 'while', 'yourselves', "mightn't", 'same', 'hers', 'no', 'whom', "that'll", 'and', 'above', 'y'}
# [nltk_data] Downloading package stopwords to C:\Users\Bryant
# [nltk_data]     Tran\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# remove stop words
df_ca['stop'] = df_ca['token'].apply(lambda x: [item for item in x if item not in stop_words])
df_ca.head()
# Out:
#         date      school state  \
# 0  24-Jan-20  Santa Cruz    CA
# 1  30-Jan-20  Santa Cruz    CA
# 2  31-Jan-20  Santa Cruz    CA
# 3   4-Feb-20  Santa Cruz    CA
# 4   4-Feb-20  Santa Cruz    CA
#
#                                              content  word_count  \
# 0  The UC Santa Cruz Student Health Center offers...       414.0
# 1  UC Santa Cruz health officials are closely mon...       382.0
# 2  Due to the dynamic situation with the coronavi...       338.0
# 3  The UC Office of the President has directed th...      1276.0
# 4  To: UC Santa Cruz Community  From: Public Affa...       989.0
#
#                                                token  \
# 0  [The, UC, Santa, Cruz, Student, Health, Center...
# 1  [UC, Santa, Cruz, health, officials, are, clos...
# 2  [Due, to, the, dynamic, situation, with, the, ...
# 3  [The, UC, Office, of, the, President, has, dir...
# 4  [To, :, UC, Santa, Cruz, Community, From, :, P...
#
#                                                 stop
# 0  [The, UC, Santa, Cruz, Student, Health, Center...
# 1  [UC, Santa, Cruz, health, officials, closely, ...
# 2  [Due, dynamic, situation, coronavirus, protect...
# 3  [The, UC, Office, President, directed, faculty...
# 4  [To, :, UC, Santa, Cruz, Community, From, :, P...

# %% [markdown]
# ### Stemming
# Stemming reduces words to their root words. For example, "washes", "washing", and "washed" all **stem**, or originate from the word "wash"

# %%
# Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()

#stemmed_words=[]
#for w in filtered_sent:
#    stemmed_words.append(ps.stem(w))

#print("Filtered Sentence:", filtered_sent)
#print("Stemmed Sentence:", stemmed_words)

# %%
df_ca['stem'] = df_ca['stop'].apply(lambda x: [ps.stem(y) for y in x])
df_ca.head()
# Out:
#         date      school state  \
# 0  24-Jan-20  Santa Cruz    CA
# 1  30-Jan-20  Santa Cruz    CA
# 2  31-Jan-20  Santa Cruz    CA
# 3   4-Feb-20  Santa Cruz    CA
# 4   4-Feb-20  Santa Cruz    CA
#
#                                              content  word_count  \
# 0  The UC Santa Cruz Student Health Center offers...       414.0
# 1  UC Santa Cruz health officials are closely mon...       382.0
# 2  Due to the dynamic situation with the coronavi...       338.0
# 3  The UC Office of the President has directed th...      1276.0
# 4  To: UC Santa Cruz Community  From: Public Affa...       989.0
#
#                                                token  \
# 0  [The, UC, Santa, Cruz, Student, Health, Center...
# 1  [UC, Santa, Cruz, health, officials, are, clos...
# 2  [Due, to, the, dynamic, situation, with, the, ...
# 3  [The, UC, Office, of, the, President, has, dir...
# 4  [To, :, UC, Santa, Cruz, Community, From, :, P...
#
#                                                 stop  \
# 0  [The, UC, Santa, Cruz, Student, Health, Center...
# 1  [UC, Santa, Cruz, health, officials, closely, ...
# 2  [Due, dynamic, situation, coronavirus, protect...
# 3  [The, UC, Office, President, directed, faculty...
# 4  [To, :, UC, Santa, Cruz, Community, From, :, P...
#
#                                                 stem
# 0  [the, UC, santa, cruz, student, health, center...
# 1  [UC, santa, cruz, health, offici, close, monit...
# 2  [due, dynam, situat, coronaviru, protect, heal...
# 3  [the, UC, offic, presid, direct, faculti, ,, s...
# 4  [To, :, UC, santa, cruz, commun, from, :, publ...

# %% [markdown]
# ### Frequency Distribution
# Time to see which words occure mo
# st frequently

# %%
# get series of all words after stemming
stem_ca = df_ca['stem'].apply(pd.Series).stack()

# %%
from nltk.probability import FreqDist
import string

# calculation word frequency
fdist_stem_ca = FreqDist(stem_ca)


# remove punctuation counts
for punc in string.punctuation:
    del fdist_stem_ca[punc]

# %%
# Frequency Distribution Plot - top 20

# for words in what students like most
fdist_stem_ca.plot(20, cumulative=False)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
analyser = SentimentIntensityAnalyzer()

# %%
# Some text taken from UC Santa Cruz's first COVID-19 update
analyser.polarity_scores(""""We know that many of you are concerned about the recent appearance of the coronavirus. 
                         Although there have been no confirmed cases on campus, we want to provide you with some 
                         information about how to protect your health.""")
# Out:
# {'neg': 0.054, 'neu': 0.852, 'pos': 0.095, 'compound': 0.1779}

# %% [markdown]
# **From lecture 6_04**
#
# "pos + neg + neu = 1"
#
# "compound score - metric that calculates sum of all the lexicon ratings and normalizes between -1(most extreme negative) and +1 (most extreme positive)
#
#     positive: compound >= 0.05
#     neutral: -0.05 < compound < 0.05
#     negative : compound <= -0.05

# %% [markdown]
# Let's start calculating the **sentiment** of the content

# %%
# get list of the 'sentences' (responses) from each individual
ca_list = list(df_ca['content'].values)

# %%
# create function that will output dataframe 
# that stores sentiment information
def get_sentiments(input_list):
    
    output = pd.DataFrame()

    for sentence in input_list:
        ss = analyser.polarity_scores(sentence)
        ss['sentence'] = sentence
        output = output.append(ss, ignore_index=True)

    return output

# %%
# get sentiment measures
ca_sentiments = get_sentiments(ca_list)

# %%
ca_sentiments.head()
# Out:
#    compound    neg    neu    pos  \
# 0   -0.9219  0.114  0.800  0.086
# 1   -0.9725  0.108  0.843  0.049
# 2    0.9246  0.031  0.898  0.071
# 3    0.9376  0.070  0.847  0.082
# 4    0.9702  0.030  0.856  0.114
#
#                                             sentence
# 0  The UC Santa Cruz Student Health Center offers...
# 1  UC Santa Cruz health officials are closely mon...
# 2  Due to the dynamic situation with the coronavi...
# 3  The UC Office of the President has directed th...
# 4  To: UC Santa Cruz Community  From: Public Affa...

# %%
ca_sentiments.describe()
# Out:
#          compound         neg         neu         pos
# count  341.000000  341.000000  341.000000  341.000000
# mean     0.743943    0.039648    0.856765    0.103528
# std      0.509846    0.028333    0.052168    0.047218
# min     -0.994500    0.000000    0.685000    0.000000
# 25%      0.886000    0.020000    0.824000    0.073000
# 50%      0.981500    0.035000    0.855000    0.104000
# 75%      0.994400    0.054000    0.888000    0.131000
# max      0.999700    0.165000    1.000000    0.278000

# %% [markdown]
# ### Now performing a similar analysis on Texas schools

# %%
#Here we are tokenizing the words and adding word counts in 
#order to explore the data numerically
df_tx['word_count'] = df_tx['content'].str.split().str.len()
df_tx['token'] = df_tx['content'].apply(word_tokenize) 

df_tx.head()
# Out:
#         date                  school state  \
# 0  30-Jan-20  Texas State University    TX
# 1  26-Feb-20  Texas State University    TX
# 2  28-Feb-20  Texas State University    TX
# 3   2-Mar-20  Texas State University    TX
# 4   5-Mar-20  Texas State University    TX
#
#                                              content  word_count  \
# 0   In response to the Novel Coronavirus outbreak...         197
# 1   Over the past several weeks, Texas State Univ...         228
# 2   Over the past several weeks, Texas State Univ...         317
# 3  Dear Texas State Community,  As news continues...         590
# 4   The City of San Marcos in coordination with H...         561
#
#                                                token
# 0  [In, response, to, the, Novel, Coronavirus, ou...
# 1  [Over, the, past, several, weeks, ,, Texas, St...
# 2  [Over, the, past, several, weeks, ,, Texas, St...
# 3  [Dear, Texas, State, Community, ,, As, news, c...
# 4  [The, City, of, San, Marcos, in, coordination,...

# %%
#just observiing the same stop words we have imported for the California schools
stop_words = set(stopwords.words('english'))

# look at stop words
print(stop_words)
# Out:
# {'both', 'needn', 'i', 'myself', 'itself', 'the', 'their', 'just', "you'll", 'through', 'is', 'about', 'any', 'at', 'once', 'more', 'have', "hadn't", 'as', 'after', 'ours', 'but', 'if', "haven't", 'there', 'themselves', "mustn't", "shouldn't", 'mustn', 'under', 'will', 'weren', 'she', 'been', 'because', 'why', "you've", 'nor', 'other', 'against', 'these', 'yours', "needn't", 'don', 'doesn', 'his', 's', 'again', 'few', "isn't", 'up', 'theirs', 'each', "you're", 'it', 'such', 'himself', 'was', 'only', 'are', 'here', 'herself', 'in', 'this', 'o', 'too', 'a', "she's", 'wasn', 'yourself', 'which', 'off', 'hadn', 're', 'had', 'me', 'couldn', 'aren', 'ourselves', 'between', 've', 'over', 'by', 'those', 'doing', 'most', 'my', 'who', 'an', 'did', 'he', 'm', 'then', 'than', 'shouldn', 'from', 'so', 'ma', 'him', 'until', 'didn', 'her', 'does', 'or', 'd', "didn't", 'out', 'them', 'll', 'we', 'haven', "don't", "doesn't", 'its', 'with', 'you', 'be', 't', "shan't", 'into', 'on', 'they', 'when', "won't", 'below', 'that', 'very', 'our', 'mightn', "wouldn't", 'am', 'hasn', 'isn', 'how', 'before', 'further', "should've", 'being', 'of', 'own', 'shan', 'what', 'to', 'can', 'some', 'for', 'not', 'where', 'your', 'now', 'during', 'do', 'all', 'won', 'should', 'wouldn', "it's", "aren't", "couldn't", "you'd", 'ain', 'has', "hasn't", "weren't", 'were', 'down', 'having', "wasn't", 'while', 'yourselves', "mightn't", 'same', 'hers', 'no', 'whom', "that'll", 'and', 'above', 'y'}

# %%
# remove stop words
df_tx['stop'] = df_tx['token'].apply(lambda x: [item for item in x if item not in stop_words])
df_tx.head()
# Out:
#         date                  school state  \
# 0  30-Jan-20  Texas State University    TX
# 1  26-Feb-20  Texas State University    TX
# 2  28-Feb-20  Texas State University    TX
# 3   2-Mar-20  Texas State University    TX
# 4   5-Mar-20  Texas State University    TX
#
#                                              content  word_count  \
# 0   In response to the Novel Coronavirus outbreak...         197
# 1   Over the past several weeks, Texas State Univ...         228
# 2   Over the past several weeks, Texas State Univ...         317
# 3  Dear Texas State Community,  As news continues...         590
# 4   The City of San Marcos in coordination with H...         561
#
#                                                token  \
# 0  [In, response, to, the, Novel, Coronavirus, ou...
# 1  [Over, the, past, several, weeks, ,, Texas, St...
# 2  [Over, the, past, several, weeks, ,, Texas, St...
# 3  [Dear, Texas, State, Community, ,, As, news, c...
# 4  [The, City, of, San, Marcos, in, coordination,...
#
#                                                 stop
# 0  [In, response, Novel, Coronavirus, outbreak, ,...
# 1  [Over, past, several, weeks, ,, Texas, State, ...
# 2  [Over, past, several, weeks, ,, Texas, State, ...
# 3  [Dear, Texas, State, Community, ,, As, news, c...
# 4  [The, City, San, Marcos, coordination, Hays, C...

# %% [markdown]
# ### Stemming
# Reducing the words to their roots

# %%
# We do not need to import the PorterStemmer module again as we did it earlier
# Initializing the port stemmer object
ps = PorterStemmer()

# %%
df_tx['stem'] = df_tx['stop'].apply(lambda x: [ps.stem(y) for y in x])
df_tx.head()
# Out:
#         date                  school state  \
# 0  30-Jan-20  Texas State University    TX
# 1  26-Feb-20  Texas State University    TX
# 2  28-Feb-20  Texas State University    TX
# 3   2-Mar-20  Texas State University    TX
# 4   5-Mar-20  Texas State University    TX
#
#                                              content  word_count  \
# 0   In response to the Novel Coronavirus outbreak...         197
# 1   Over the past several weeks, Texas State Univ...         228
# 2   Over the past several weeks, Texas State Univ...         317
# 3  Dear Texas State Community,  As news continues...         590
# 4   The City of San Marcos in coordination with H...         561
#
#                                                token  \
# 0  [In, response, to, the, Novel, Coronavirus, ou...
# 1  [Over, the, past, several, weeks, ,, Texas, St...
# 2  [Over, the, past, several, weeks, ,, Texas, St...
# 3  [Dear, Texas, State, Community, ,, As, news, c...
# 4  [The, City, of, San, Marcos, in, coordination,...
#
#                                                 stop  \
# 0  [In, response, Novel, Coronavirus, outbreak, ,...
# 1  [Over, past, several, weeks, ,, Texas, State, ...
# 2  [Over, past, several, weeks, ,, Texas, State, ...
# 3  [Dear, Texas, State, Community, ,, As, news, c...
# 4  [The, City, San, Marcos, coordination, Hays, C...
#
#                                                 stem
# 0  [In, respons, novel, coronaviru, outbreak, ,, ...
# 1  [over, past, sever, week, ,, texa, state, univ...
# 2  [over, past, sever, week, ,, texa, state, univ...
# 3  [dear, texa, state, commun, ,, As, news, conti...
# 4  [the, citi, san, marco, coordin, hay, counti, ...

# %% [markdown]
# ### Creating a frequency distribution
# We can at somepoint compare the words that showed up more frequently between the states

# %%
#get series of all words
stem_tx = df_tx['stem'].apply(pd.Series).stack()

# %%
# calculation word frequency
fdist_stem_tx = FreqDist(stem_tx)


# remove punctuation counts
for punc in string.punctuation:
    del fdist_stem_tx[punc]

# %%
#Frequency Distribution Plot - top 20 for words 
#in what students like most
fdist_stem_tx.plot(20, cumulative=False)

# %%
# get list of the 'sentences' (responses) from each individual
tx_list = list(df_tx['content'].values)

# %%
# use the function we created earlier that will output dataframe 
# that stores sentiment information
tx_sentiments = get_sentiments(tx_list)
tx_sentiments.head()
# Out:
#    compound    neg    neu    pos  \
# 0    0.8720  0.021  0.905  0.074
# 1   -0.8360  0.069  0.908  0.023
# 2   -0.8689  0.066  0.904  0.030
# 3    0.6386  0.060  0.869  0.071
# 4    0.0812  0.067  0.869  0.064
#
#                                             sentence
# 0   In response to the Novel Coronavirus outbreak...
# 1   Over the past several weeks, Texas State Univ...
# 2   Over the past several weeks, Texas State Univ...
# 3  Dear Texas State Community,  As news continues...
# 4   The City of San Marcos in coordination with H...

# %%
tx_sentiments.describe()
# Out:
#          compound         neg         neu         pos
# count  192.000000  192.000000  192.000000  192.000000
# mean     0.729663    0.032661    0.861734    0.105615
# std      0.491371    0.033305    0.063968    0.055045
# min     -0.977200    0.000000    0.530000    0.000000
# 25%      0.814375    0.012000    0.821750    0.072750
# 50%      0.970000    0.023000    0.860500    0.105500
# 75%      0.989900    0.044000    0.900250    0.138250
# max      0.999400    0.272000    1.000000    0.362000

# %% [markdown]
# ### Lastly performing a similar analysis on Florida schools

# %%
#Here we are tokenizing the words and adding word counts in 
#order to explore the data numerically
df_fl['word_count'] = df_fl['content'].str.split().str.len()
df_fl['token'] = df_fl['content'].apply(word_tokenize) 

df_fl.head()
# Out:
#           date                         school state  \
# 0  21-May-2020  University of Central Florida    FL
# 1  20-May-2020  University of Central Florida    FL
# 2  13-May-2020  University of Central Florida    FL
# 3  13-May-2020  University of Central Florida    FL
# 4  11-May-2020  University of Central Florida    FL
#
#                                              content  word_count  \
# 0  As we are all adjusting to the different reali...         696
# 1  COVID-19 has impacted all of us in some way. T...         882
# 2  As businesses and other entities across the st...         594
# 3  We would like to thank you for your continued ...         716
# 4  To continue to support our Knights during this...         260
#
#                                                token
# 0  [As, we, are, all, adjusting, to, the, differe...
# 1  [COVID-19, has, impacted, all, of, us, in, som...
# 2  [As, businesses, and, other, entities, across,...
# 3  [We, would, like, to, thank, you, for, your, c...
# 4  [To, continue, to, support, our, Knights, duri...

# %%
# remove stop words
df_fl['stop'] = df_fl['token'].apply(lambda x: [item for item in x if item not in stop_words])
df_fl.head()
# Out:
#           date                         school state  \
# 0  21-May-2020  University of Central Florida    FL
# 1  20-May-2020  University of Central Florida    FL
# 2  13-May-2020  University of Central Florida    FL
# 3  13-May-2020  University of Central Florida    FL
# 4  11-May-2020  University of Central Florida    FL
#
#                                              content  word_count  \
# 0  As we are all adjusting to the different reali...         696
# 1  COVID-19 has impacted all of us in some way. T...         882
# 2  As businesses and other entities across the st...         594
# 3  We would like to thank you for your continued ...         716
# 4  To continue to support our Knights during this...         260
#
#                                                token  \
# 0  [As, we, are, all, adjusting, to, the, differe...
# 1  [COVID-19, has, impacted, all, of, us, in, som...
# 2  [As, businesses, and, other, entities, across,...
# 3  [We, would, like, to, thank, you, for, your, c...
# 4  [To, continue, to, support, our, Knights, duri...
#
#                                                 stop
# 0  [As, adjusting, different, realities, COVID-19...
# 1  [COVID-19, impacted, us, way, ., The, disrupti...
# 2  [As, businesses, entities, across, state, begi...
# 3  [We, would, like, thank, continued, understand...
# 4  [To, continue, support, Knights, challenging, ...

# %%
df_fl['stem'] = df_fl['stop'].apply(lambda x: [ps.stem(y) for y in x])
df_fl.head()
# Out:
#           date                         school state  \
# 0  21-May-2020  University of Central Florida    FL
# 1  20-May-2020  University of Central Florida    FL
# 2  13-May-2020  University of Central Florida    FL
# 3  13-May-2020  University of Central Florida    FL
# 4  11-May-2020  University of Central Florida    FL
#
#                                              content  word_count  \
# 0  As we are all adjusting to the different reali...         696
# 1  COVID-19 has impacted all of us in some way. T...         882
# 2  As businesses and other entities across the st...         594
# 3  We would like to thank you for your continued ...         716
# 4  To continue to support our Knights during this...         260
#
#                                                token  \
# 0  [As, we, are, all, adjusting, to, the, differe...
# 1  [COVID-19, has, impacted, all, of, us, in, som...
# 2  [As, businesses, and, other, entities, across,...
# 3  [We, would, like, to, thank, you, for, your, c...
# 4  [To, continue, to, support, our, Knights, duri...
#
#                                                 stop  \
# 0  [As, adjusting, different, realities, COVID-19...
# 1  [COVID-19, impacted, us, way, ., The, disrupti...
# 2  [As, businesses, entities, across, state, begi...
# 3  [We, would, like, thank, continued, understand...
# 4  [To, continue, support, Knights, challenging, ...
#
#                                                 stem
# 0  [As, adjust, differ, realiti, covid-19, ,, att...
# 1  [covid-19, impact, us, way, ., the, disrupt, s...
# 2  [As, busi, entiti, across, state, begin, bring...
# 3  [We, would, like, thank, continu, understand, ...
# 4  [To, continu, support, knight, challeng, perio...

# %% [markdown]
# ### Creating a frequency distribution
# We can at somepoint compare the words that showed up more frequently between the states

# %%
#get series of all words
stem_fl = df_fl['stem'].apply(pd.Series).stack()

# %%
# calculation word frequency
fdist_stem_fl = FreqDist(stem_fl)


# remove punctuation counts
for punc in string.punctuation:
    del fdist_stem_fl[punc]

# %%
#Frequency Distribution Plot - top 20 for words 
#in what students like most
fdist_stem_fl.plot(20, cumulative=False)

# %%
# get list of the 'sentences' (responses) from each individual
fl_list = list(df_fl['content'].values)

# %%
# use the function we created earlier that will output dataframe 
# that stores sentiment information
fl_sentiments = get_sentiments(fl_list)
fl_sentiments.head()
# Out:
#    compound    neg    neu    pos  \
# 0    0.9990  0.009  0.811  0.180
# 1    0.9961  0.030  0.856  0.114
# 2    0.9977  0.016  0.832  0.152
# 3    0.9994  0.019  0.777  0.204
# 4    0.8534  0.006  0.942  0.052
#
#                                             sentence
# 0  As we are all adjusting to the different reali...
# 1  COVID-19 has impacted all of us in some way. T...
# 2  As businesses and other entities across the st...
# 3  We would like to thank you for your continued ...
# 4  To continue to support our Knights during this...

# %%
fl_sentiments.describe()
# Out:
#          compound        neg         neu         pos
# count  167.000000  167.00000  167.000000  167.000000
# mean     0.759995    0.03206    0.859269    0.108593
# std      0.503404    0.02692    0.052291    0.046333
# min     -0.985500    0.00000    0.707000    0.000000
# 25%      0.879650    0.01400    0.822500    0.079000
# 50%      0.978300    0.02700    0.856000    0.105000
# 75%      0.994300    0.04350    0.893000    0.142000
# max      0.999400    0.12600    1.000000    0.240000
